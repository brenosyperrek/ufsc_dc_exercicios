# %% [markdown]
# <a href="https://colab.research.google.com/github/brenosyperrek/ufsc_dc_exercicios/blob/main/Exerc%C3%ADcio_An%C3%A1lise_Explorat%C3%B3ria_de_Dados_Resolvido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Exercícios Análise Exploratória de Dados - Conjunto de dados Iris
# Disciplina de Data Mining - INE5644 - CTC/INE/UFSC
#
# Prof. Jônata Tyska Carvalho

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ###Carrega o conjunto de dados

# %%
url = "https://codigos.ufsc.br/jonata.tyska/repositorio/-/raw/master/datasets/iris.csv"

# Read dataset to pandas dataframe
dataset = pd.read_csv(url)

# %% [markdown]
# **Exercício 1.** Qual o tamanho do conjunto de dados carregado (instâncias e atributos)?

# %%
print(dataset.shape)
#ou
dataset.info()
# Out:
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Exercício 2.** Quais são as colunas do conjunto de dados?

# %%
print(dataset.columns)
#ou
dataset.head(15)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa

# %% [markdown]
# **Exercício 3.** Quantas instâncias de cada classe existem no conjunto de dados?

# %%
dataset['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ou

# %%
sns.countplot(x='species',data=dataset)

# %% [markdown]
# **Exercício 4.** Para cada atributo, calcule o número de valores disponíveis (contagem), a média, o desvio padrão, o valor mínimo, o máximo, o primeiro (Q1), segundo(Q2) e terceiro (Q3) quartis e o valor máximo.

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **Exercício 5.** Visualize os dados usando histogramas para cada um dos atributos.

# %%
sns.histplot(dataset,x="sepal_length",binwidth=0.5)

# %%
sns.histplot(dataset,x="sepal_width",binwidth=0.5)

# %%
sns.histplot(dataset,x="petal_length",binwidth=0.5, hue="species", multiple="stack")

# %%
sns.histplot(dataset,x="petal_width",binwidth=0.5, hue="species", multiple="stack")

# %% [markdown]
# **Exercício 6.** Visualize os dados usando gráficos de dispersão para cada dupla de atributos.

# %%
sns.pairplot(dataset)

# %% [markdown]
# ou

# %%
sns.pairplot(dataset,hue="species")

# %% [markdown]
# **Exercício 7.** Use um tipo de gráfico que ajude a detectar valores atípicos (*outliers*)

# %%
sns.boxplot(x="species", y="petal_length", data=dataset)

# %%
sns.boxplot(x="species", y="petal_width", data=dataset)

# %%
sns.boxplot(x="species", y="sepal_width", data=dataset)

# %%
sns.boxplot(x="species", y="sepal_length", data=dataset)

# %% [markdown]
# **Exercício 8.** Visualize a correlação entre as variáveis

# %%
sns.heatmap(dataset.corr(),annot=True);

# %%
dataset.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# Material parcialmente baseado em: https://medium.com/swlh/exploratory-data-analysis-of-iris-dataset-2ab58e1a5dc6
